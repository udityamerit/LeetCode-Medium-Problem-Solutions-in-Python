# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1 in Python

# %%
class Solution:
    def minimumSteps(self, s: str) -> int:
        swap, black = 0,0
        for char in s:
            if char=="0":
                swap = swap+black
            else:
                black+= 1
        return swap
