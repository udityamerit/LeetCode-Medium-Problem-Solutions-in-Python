# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution in python

# %%
from collections import Counter
class Solution:
    def findLonely(self, nums: List[int]) -> List[int]:
        cnt = Counter(nums)
        return [x for x in cnt if cnt[x] == 1 and (x+1) not in cnt and (x-1) not in cnt]
