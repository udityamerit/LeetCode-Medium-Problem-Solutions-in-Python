# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1 in Python

# %%
class Solution:
    def maximumBeauty(self, nums: List[int], k: int) -> int:
        nums.sort()
        l = 0
        for num in nums:
            if num - nums[l] > 2*k:
                l += 1
        return len(nums) - l
