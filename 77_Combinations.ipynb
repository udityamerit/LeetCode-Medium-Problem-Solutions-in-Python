# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1 in python

# %%
class Solution:
    def combine(self, n: int, k: int) -> List[List[int]]:
        l = []
        test_list = [i for i in range(1,n+1)]
        c = list(combinations(test_list, k))
        # print(c)
        return c
