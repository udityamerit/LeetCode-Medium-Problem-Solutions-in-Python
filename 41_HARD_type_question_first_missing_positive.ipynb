# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def firstMissingPositive(self, nums: List[int]) -> int:
        l = set(range(1,len(nums)+2))
        print(l)
        for i in nums:
            if i in l:
                l.remove(i)
        return min(l)
