# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def checkInclusion(self, s1: str, s2: str) -> bool:
        # if s1==s2:
        #     return True
        # permlist = permutations(s1)
        # l = ["".join(i) for i in permlist]
        # print(l)
        # s = [i for i in s2]
        # k = ["".join(i) for i in set(list(combinations(s,len(s1))))]
        # print(k)
        # if len(s1)>3:
        #     for i in l:
        #         if i == s1:
        #             l.remove(i)
        
        # print(l)
        # for i in l:
        #     if i  in s2:
        #         print(i)
        #         return True
        
        # return False
        
        window = len(s1)
        s1_c = Counter(s1)
        
        for i in range(len(s2)-window+1):
            s2_c = Counter(s2[i:i+window])
            if s2_c == s1_c:
                return True
        return False
