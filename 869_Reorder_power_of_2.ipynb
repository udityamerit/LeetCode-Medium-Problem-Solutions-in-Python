# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def reorderedPowerOf2(self, n: int) -> bool:
        # l = [i for i in str(n)]
        # k = []
        # print(l)
        # l = l[::-1]
        # print(l)
        # p = int("".join(l))
        # print(p)
        # c1 = log2(p)/log2(2)
        # c = log2(n)/log2(2)
        # k.append(c1==int(c1))
        # k.append(c==int(c))
        # print(k)
        # if l[0]=='0':
        #     k.remove(True)
        # print(k)
        # if True in k:
        #     return True
        # else:
        #     return False
        num = sorted(str(n))
        for i in range(32):
            currnum = sorted(str(2**i))
            if num==currnum:
                return True
        return False
